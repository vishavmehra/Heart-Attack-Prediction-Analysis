# %% [markdown]
# ***The data has been fetched from Kagel repository and have been uploaded by BMC medical informatics. The dataset contains the record of 299 patients and have been divided into 10 different classes and one target variable.***
#
# ***The dataset is accessed in google colab using panda library The data has been fetched from Kagel repository and have been uploaded by BMC medical informatics. The dataset contains the record of 299 patients and have been divided into 10 different classes and one target variable.***
#
#
# The dataset is accessed in google colab using panda library

# %%
import pandas as pd

# %%
CU=pd.read_csv('/content/heart_failure_clinical_records_dataset 2.csv')
CU
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %% [markdown]
# **Exploratory data analysis (EDA)**
#
# It is a process of performing initial investigations on the dataset in order to discover patterns and receive anomalies.
#
# Methods we have performed for exploratory data analysis
#
#
# 1.  Max() and Min() - In order to find and highlight the maximum and minimum values of each class
# 2.  Describe()- it returns the description od data in dataFrame
# 3.  Dtypes()- It is used to classify the data into their respective data types such as int, float etc.

# %%
CU.style.highlight_max()
# Out:
# <style type="text/css">
# ...

# %%
CU.index
# Out:
# RangeIndex(start=0, stop=299, step=1)

# %%
CU.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
CU.max()
# Out:
# age                             95.0
# anaemia                          1.0
# creatinine_phosphokinase      7861.0
# diabetes                         1.0
# ejection_fraction               80.0
# high_blood_pressure              1.0
# platelets                   850000.0
# serum_creatinine                 9.4
# serum_sodium                   148.0
# sex                              1.0
# smoking                          1.0
# time                           285.0
# DEATH_EVENT                      1.0
# dtype: float64

# %%
CU.min()
# Out:
# age                            40.0
# anaemia                         0.0
# creatinine_phosphokinase       23.0
# diabetes                        0.0
# ejection_fraction              14.0
# high_blood_pressure             0.0
# platelets                   25100.0
# serum_creatinine                0.5
# serum_sodium                  113.0
# sex                             0.0
# smoking                         0.0
# time                            4.0
# DEATH_EVENT                     0.0
# dtype: float64

# %%
CU.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
CU.dtypes
# Out:
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object

# %% [markdown]
# **Statisitcal data Analysis (SDA)**
#
# Statistical analysis is a scientific tool that helps collect and analyze large amounts of data to identify common patterns and trends to convert them into meaningful information
#
# Below given code use matplotlib library to draw relationship between target variable and classes.

# %% [markdown]
# **1. Scatter plot between Age and target variable (DEATH_EVENT)**

# %%
import matplotlib.pyplot as plt
x= CU['age']
y =CU['DEATH_EVENT']
plt.xlabel('age')
plt.ylabel('DEATH_EVENT')
plt.scatter(x, y, marker = "*",color = "red")
plt.show()

# %% [markdown]
# **2. Histogram between SEX and target variable (DEATH_EVENT)**

# %%
#histogram plot
import matplotlib.pyplot as plt
x=tuple(range(768))
x = ['sex']
y = ['DEATH_EVENT']

plt.xlabel('sex')
plt.ylabel('DEATH_EVENT')
plt.title('sex and deaths')

plt.hist(x, color = "green", bins=50)

plt.show()

# %% [markdown]
# **3. Scatter plot between creatinine_phosphokinase and target variable (DEATH_EVENT)**

# %%
import matplotlib.pyplot as plt
x= CU['creatinine_phosphokinase']
y =CU['DEATH_EVENT']
plt.xlabel('creatinine_phosphokinase')

plt.ylabel('DEATH_EVENT')
plt.scatter(x, y, marker = "*",color = "red")
plt.show()

# %% [markdown]
# **4. Bar Graph between time and target variable (DEATH_EVENT)**

# %%
import matplotlib.pyplot as plt
x= CU['time']
y =CU['DEATH_EVENT']
plt.xlabel('time')

plt.ylabel('DEATH_EVENT')
plt.bar(x, y,color = "red")
plt.show()

# %% [markdown]
# **5. Scatter plot between serum_sodium and target variable (DEATH_EVENT)**

# %%
import matplotlib.pyplot as plt
x= CU['serum_sodium']
y =CU['DEATH_EVENT']
plt.xlabel('serum_sodium')

plt.ylabel('DEATH_EVENT')
plt.scatter(x, y, marker = ".",color = "red")
plt.show()

# %% [markdown]
# An **ROC curve** (receiver operating characteristic curve) is a graph showing the performance of a classification model at all classification thresholds. This curve plots two parameters:
#
# True Positive Rate
# False Positive Rate
#
# We have plotted ROC curve in Logistic regression to show the performace of model in Heart Failure dataset.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import matplotlib.pyplot as plt
data=pd.read_csv('/content/heart_failure_clinical_records_dataset 2.csv')


#define the predictor variables and the response variable
X = data[['age', 'anaemia', 'diabetes']]
y = data['DEATH_EVENT']

#split the dataset into training (70%) and testing (30%) sets
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=0)

#instantiate the model
log_regression = LogisticRegression()

#fit the model using the training data
log_regression.fit(X_train,y_train)
y_pred_proba = log_regression.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr)
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# In order to compare different machine learning models on Heart failure database we then used heart_disease dataset that comes along with **Pycaret library** providing us the advantage to firect compare
# models using setup and compare model function

# %%
# !pip install pycaret &>/dev/null
print(" Pycaret installed sucessfully ")
# Out:
#  Pycaret installed sucessfully

# %%
pip uninstall scipy
# Out:
# Found existing installation: scipy 1.10.1
# Uninstalling scipy-1.10.1:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/scipy-1.10.1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/scipy.libs/libgfortran-040039e1.so.5.0.0
#     /usr/local/lib/python3.10/dist-packages/scipy.libs/libopenblasp-r0-41284840.3.18.so
#     /usr/local/lib/python3.10/dist-packages/scipy.libs/libquadmath-96973f99.so.0.0.0
#     /usr/local/lib/python3.10/dist-packages/scipy/*
# Proceed (Y/n)?
#   Successfully uninstalled scipy-1.10.1

# %%
# !pip install h5py
# !pip install typing-extensions
# !pip install wheel

# %%
# !pip uninstall daal
# !pip install daal==2021.4.0
# !pip uninstall numpy
# !pip install numpy==1.8.2
# !pip install numpy==1.21.5
# !pip uninstall requests
# !pip install requests==2.25.1
# Out:
#   ERROR: Operation cancelled by user
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 17.1 MB/s eta 0:00:00
# ...
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3108, in _dep_map
#     return self.__dep_map
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2901, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 169, in exc_logging_wrapper
# ...

# %%
from pycaret.datasets import get_data
dataSets = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
vishav = get_data('heart_disease')
# Out:
#    age  sex  chest pain type  resting blood pressure  \
# 0   70    1                4                     130
# 1   67    0                3                     115
# 2   57    1                2                     124
# 3   64    1                4                     128
# 4   74    0                2                     120
#
#    serum cholestoral in mg/dl        fasting blood sugar > 120 mg/dl   \
# 0                               322                                 0
# 1                               564                                 0
# 2                               261                                 0
# 3                               263                                 0
# 4                               269                                 0
#
#    resting electrocardiographic results  maximum heart rate achieved    \
# 0                                     2                            109
# 1                                     2                            160
# ...

# %% [markdown]
# **1. USING COMPARE MODEL FUNCTION**

# %%
from pycaret.datasets import get_data
vishav = get_data('heart_disease')
from pycaret.classification import *
s = setup(data = vishav , target  = 'Disease', remove_outliers = True, outliers_threshold = 0.05)
cm = compare_models()
# Out:
#    age  sex  chest pain type  resting blood pressure  \
# 0   70    1                4                     130
# 1   67    0                3                     115
# 2   57    1                2                     124
# 3   64    1                4                     128
# 4   74    0                2                     120
#
#    serum cholestoral in mg/dl        fasting blood sugar > 120 mg/dl   \
# 0                               322                                 0
# 1                               564                                 0
# 2                               261                                 0
# 3                               263                                 0
# 4                               269                                 0
#
#    resting electrocardiographic results  maximum heart rate achieved    \
# 0                                     2                            109
# 1                                     2                            160
# ...

# %% [markdown]
# **2. USING COMPARE MODEL FUNCTION ALONG PCA(PRINCIPAL COMPONENT ANALYSIS)**
#
# Principal Component Analysis, or PCA, is a dimensionality-reduction method that is often used to reduce the dimensionality of large data sets, by transforming a large set of variables into a smaller one that still contains most of the information in the large set.

# %%
from pycaret.datasets import get_data
vishav = get_data('heart_disease')
from pycaret.classification import *
s = setup(data = vishav , target  = 'Disease', pca= True, pca_method='linear')
cm = compare_models()
# Out:
#    age  sex  chest pain type  resting blood pressure  \
# 0   70    1                4                     130
# 1   67    0                3                     115
# 2   57    1                2                     124
# 3   64    1                4                     128
# 4   74    0                2                     120
#
#    serum cholestoral in mg/dl        fasting blood sugar > 120 mg/dl   \
# 0                               322                                 0
# 1                               564                                 0
# 2                               261                                 0
# 3                               263                                 0
# 4                               269                                 0
#
#    resting electrocardiographic results  maximum heart rate achieved    \
# 0                                     2                            109
# 1                                     2                            160
# ...

# %% [markdown]
# **3. USING COMPARE MODEL FUNCTION ALONG OUTLIER REMOVAL AND NORMALIZATION**
#
# Normalization is a technique often applied as part of data preparation for machine learning. The goal of normalization is to change the values of numeric columns in the dataset to use a common scale, without distorting differences in the ranges of values or losing information.

# %%
from pycaret.datasets import get_data
vishav = get_data('heart_disease')
from pycaret.classification import *
s = setup(data = vishav , target  = 'Disease', remove_outliers = True, outliers_threshold= 0.05, normalize= True, normalize_method="zscore"  )
cm = compare_models()
# Out:
#    age  sex  chest pain type  resting blood pressure  \
# 0   70    1                4                     130
# 1   67    0                3                     115
# 2   57    1                2                     124
# 3   64    1                4                     128
# 4   74    0                2                     120
#
#    serum cholestoral in mg/dl        fasting blood sugar > 120 mg/dl   \
# 0                               322                                 0
# 1                               564                                 0
# 2                               261                                 0
# 3                               263                                 0
# 4                               269                                 0
#
#    resting electrocardiographic results  maximum heart rate achieved    \
# 0                                     2                            109
# 1                                     2                            160
# ...
